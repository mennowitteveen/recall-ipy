# %%
from recall_ipy import init
init('/Users/patarapolw/PycharmProjects/chinese/zhlevel.srs', silent=True)

# %%
from recall_ipy.deck import show_decks
show_decks('tag:微信')
# Out:
# <style>
# span {
#     display: inline-block;
# }
#
# .counter-container {
#     margin-left: 2em;
#     left: 50%;
#     display: inline-block;
#     position: absolute;
# }
#
# .counter {
#     margin-left: 1em;
#     width: 3em;
#     text-align: right;
# }
#
# .counter-due {
#     color: red;
# }
#
# .counter-remaining {
#     color: green;
# }
#
# .link {
#     color: blue;
#     text-decoration: underline;
#     display: inline-block;
# }
# </style>
#
# <ul id='showDeckArea'></ul>
#
# <script>
# String.prototype.hashCode = function() {
#   var hash = 0, i, chr;
#   if (this.length === 0) return hash;
#   for (i = 0; i < this.length; i++) {
#     chr   = this.charCodeAt(i);
#     hash  = ((hash << 5) - hash) + chr;
#     hash |= 0; // Convert to 32bit integer
#   }
#   return hash.toString(16).replace('-', '_');
# };
# </script>
# <script>
# var executePython = function(pythonStr) {
#     return new Promise((resolve, reject) => {
#         const callbacks = {
# ...

# %%
from recall_ipy.review import ReviewDeck
review_deck = ReviewDeck("ZhLevel::Hanzi::中英::01-10 Pleasant", filter_="tag:微信")
review_deck
# Out:
# <style id='srs-css'></style>
#
# <div id='srs-front' class='srs-front'></div>
# <div id='srs-back' class='srs-back'></div>
# <div id='srs-buttonArea'>
#     <button id='srs-showAnswer' type='button' class='btn btn-default srs-front'>
#         Show Answer
#     </button>
#
#     <button id='srs-wrong' type='button' class='btn btn-danger srs-back'>
#         Wrong
#     </button>
#
#     <button id='srs-right' type='button' class='btn btn-success srs-back'>
#         Right
#     </button>
#
#     <button id='srs-easy' type='button' class='btn btn-primary srs-back'>
#         Easy
#     </button>
# </div>
#
# <script id='srs-js'></script>
#
# <script>
# var executePython = function(pythonStr) {
#     return new Promise((resolve, reject) => {
#         const callbacks = {
#             shell: {
#                 reply: data=>{
#                     // console.log(data);
#                     const status = data.content.status;
# ...

# %%
review_deck.get_stat()

# %%
review_deck.get(-1)
