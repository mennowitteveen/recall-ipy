# %%
from recall_ipy import init
init('/Users/patarapolw/PycharmProjects/chinese/zhlevel.srs')
# Out:
# <style>
# span {
#     display: inline-block;
# }
#
# .counter-container {
#     margin-left: 2em;
#     left: 50%;
#     display: inline-block;
#     position: absolute;
# }
#
# .counter {
#     margin-left: 1em;
#     width: 3em;
#     text-align: right;
# }
#
# .counter-due {
#     color: red;
# }
#
# .counter-remaining {
#     color: green;
# }
# </style>
#
# <ul id='showDeckArea'></ul>
#
# <script>
# String.prototype.hashCode = function() {
#   var hash = 0, i, chr;
#   if (this.length === 0) return hash;
#   for (i = 0; i < this.length; i++) {
#     chr   = this.charCodeAt(i);
#     hash  = ((hash << 5) - hash) + chr;
#     hash |= 0; // Convert to 32bit integer
#   }
#   return hash.toString(16).replace('-', '_');
# };
# </script>
# <script>
# var executePython = function(pythonStr) {
#     return new Promise((resolve, reject) => {
#         const callbacks = {
#             shell: {
#                 reply: data=>{
#                     // console.log(data);
#                     const status = data.content.status;
#                     if(status !== 'ok') alert(`${pythonStr}: ${JSON.stringify(data.content)}`)
#                     resolve(data);
#                 }
#             }
#         };
#         Jupyter.notebook.kernel.execute(pythonStr, callbacks);
#     });
# }
#
# var executePythonOutput = function(pythonStr) {
#     return new Promise((resolve, reject) => {
#         const callbacks = {
#             iopub: {
#                 output: data=>{
#                     // console.log(data.content);
#                     resolve(data.content.data['text/plain'])
#                 }
#             }
#         };
#         Jupyter.notebook.kernel.execute(pythonStr, callbacks, {silent: false});
#     });
# }
#
# var consoleLogPythonEndpoints = function(pythonStr) {
#     const callbacks = {
#         shell: {
#             reply: data=>{
#                 console.log('reply', data);
#             },
#             payload: {
#                 set_next_input: data=>{
#                     console.log('data', data);
#                 }
#             }
#         },
#         iopub: {
#             output: data=>{
#                 console.log('output', data)
#             },
#             clear_output: data=>{
#                 console.log('clear_output', data)
#             },
#         },
#         input: data=>{
#             console.log('input', data);
#         }
#     }
#     Jupyter.notebook.kernel.execute(pythonStr, callbacks, {silent: false, allow_stdin: true});
# }
#
# var executePythonOutputInNextCell = function(pythonStr) {
#     const nb = Jupyter.notebook;
#
#     nb.insert_cell_below()
#     const nbCell = nb.get_next_cell();
#     nbCell.code_mirror.doc.replaceSelection(pythonStr);
#
#     nb.select_next()
#     nb.execute_cell();
# }
# </script>
#
# <script>
# var deckDict = {
#   "nodes": [
#     {
#       "text": "ZhLevel",
#       "nodes": [
#         {
#           "text": "Hanzi",
#           "nodes": [
#             {
#               "text": "中英",
#               "nodes": [
#                 {
#                   "text": "01-10 Pleasant",
#                   "nodes": [
#                     {
#                       "text": "Level 01",
#                       "deck": 1
#                     },
#                     {
#                       "text": "Level 02",
#                       "deck": 6
#                     },
#                     {
#                       "text": "Level 03",
#                       "deck": 15
#                     },
#                     {
#                       "text": "Level 04",
#                       "deck": 20
#                     },
#                     {
#                       "text": "Level 05",
#                       "deck": 28
#                     },
#                     {
#                       "text": "Level 06",
#                       "deck": 35
#                     },
#                     {
#                       "text": "Level 07",
#                       "deck": 39
#                     },
#                     {
#                       "text": "Level 08",
#                       "deck": 43
#                     },
#                     {
#                       "text": "Level 09",
#                       "deck": 47
#                     },
#                     {
#                       "text": "Level 10",
#                       "deck": 55
#                     }
#                   ]
#                 },
#                 {
#                   "text": "11-20 Painful",
#                   "nodes": [
#                     {
#                       "text": "Level 11",
#                       "deck": 66
#                     },
#                     {
#                       "text": "Level 12",
#                       "deck": 79
#                     },
#                     {
#                       "text": "Level 13",
#                       "deck": 85
#                     },
#                     {
#                       "text": "Level 14",
#                       "deck": 91
#                     },
#                     {
#                       "text": "Level 15",
#                       "deck": 95
#                     },
#                     {
#                       "text": "Level 16",
#                       "deck": 101
#                     },
#                     {
#                       "text": "Level 17",
#                       "deck": 106
#                     },
#                     {
#                       "text": "Level 18",
#                       "deck": 111
#                     },
#                     {
#                       "text": "Level 19",
#                       "deck": 116
#                     },
#                     {
#                       "text": "Level 20",
#                       "deck": 127
#                     }
#                   ]
#                 },
#                 {
#                   "text": "21-30 Death",
#                   "nodes": [
#                     {
#                       "text": "Level 21",
#                       "deck": 137
#                     },
#                     {
#                       "text": "Level 22",
#                       "deck": 160
#                     },
#                     {
#                       "text": "Level 23",
#                       "deck": 165
#                     },
#                     {
#                       "text": "Level 24",
#                       "deck": 170
#                     },
#                     {
#                       "text": "Level 25",
#                       "deck": 174
#                     },
#                     {
#                       "text": "Level 26",
#                       "deck": 180
#                     },
#                     {
#                       "text": "Level 27",
#                       "deck": 185
#                     },
#                     {
#                       "text": "Level 28",
#                       "deck": 191
#                     },
#                     {
#                       "text": "Level 29",
#                       "deck": 197
#                     },
#                     {
#                       "text": "Level 30",
#                       "deck": 202
#                     }
#                   ]
#                 },
#                 {
#                   "text": "31-40 Hell",
#                   "nodes": [
#                     {
#                       "text": "Level 31",
#                       "deck": 220
#                     },
#                     {
#                       "text": "Level 32",
#                       "deck": 250
#                     },
#                     {
#                       "text": "Level 33",
#                       "deck": 258
#                     },
#                     {
#                       "text": "Level 34",
#                       "deck": 264
#                     },
#                     {
#                       "text": "Level 35",
#                       "deck": 268
#                     },
#                     {
#                       "text": "Level 36",
#                       "deck": 275
#                     },
#                     {
#                       "text": "Level 37",
#                       "deck": 280
#                     },
#                     {
#                       "text": "Level 38",
#                       "deck": 285
#                     },
#                     {
#                       "text": "Level 39",
#                       "deck": 290

# %%
ReviewDeck("ZhLevel::Hanzi::中英::01-10 Pleasant")
# Out:
# <style id='srs-css'></style>
#
# <div id='srs-front' class='srs-front'></div>
# <div id='srs-back' class='srs-back'></div>
# <div id='srs-buttonArea'>
#     <button id='srs-showAnswer' type='button' class='btn btn-default srs-front'>
#         Show Answer
#     </button>
#
#     <button id='srs-wrong' type='button' class='btn btn-danger srs-back'>
#         Wrong
#     </button>
#
#     <button id='srs-right' type='button' class='btn btn-success srs-back'>
#         Right
#     </button>
#
#     <button id='srs-easy' type='button' class='btn btn-primary srs-back'>
#         Easy
#     </button>
# </div>
#
# <script id='srs-js'></script>
#
# <script>
# var executePython = function(pythonStr) {
#     return new Promise((resolve, reject) => {
#         const callbacks = {
#             shell: {
#                 reply: data=>{
#                     // console.log(data);
#                     const status = data.content.status;
#                     if(status !== 'ok') alert(`${pythonStr}: ${JSON.stringify(data.content)}`)
#                     resolve(data);
#                 }
#             }
#         };
#         Jupyter.notebook.kernel.execute(pythonStr, callbacks);
#     });
# }
#
# var executePythonOutput = function(pythonStr) {
#     return new Promise((resolve, reject) => {
#         const callbacks = {
#             iopub: {
#                 output: data=>{
#                     // console.log(data.content);
#                     resolve(data.content.data['text/plain'])
#                 }
#             }
#         };
#         Jupyter.notebook.kernel.execute(pythonStr, callbacks, {silent: false});
#     });
# }
#
# var consoleLogPythonEndpoints = function(pythonStr) {
#     const callbacks = {
#         shell: {
#             reply: data=>{
#                 console.log('reply', data);
#             },
#             payload: {
#                 set_next_input: data=>{
#                     console.log('data', data);
#                 }
#             }
#         },
#         iopub: {
#             output: data=>{
#                 console.log('output', data)
#             },
#             clear_output: data=>{
#                 console.log('clear_output', data)
#             },
#         },
#         input: data=>{
#             console.log('input', data);
#         }
#     }
#     Jupyter.notebook.kernel.execute(pythonStr, callbacks, {silent: false, allow_stdin: true});
# }
#
# var executePythonOutputInNextCell = function(pythonStr) {
#     const nb = Jupyter.notebook;
#
#     nb.insert_cell_below()
#     const nbCell = nb.get_next_cell();
#     nbCell.code_mirror.doc.replaceSelection(pythonStr);
#
#     nb.select_next()
#     nb.execute_cell();
# }
# </script>
#
# <script>
# var cardIds = [7, 2300, 890, 470, 638, 2315, 1208, 1847, 1642, 1738, 2073, 959, 542, 902, 1965, 2186, 1145, 164, 1992, 800, 1778, 1510, 1178, 269, 2064, 620, 2234, 2312, 52, 344, 112, 2327, 76, 404, 2109, 1091, 1805, 1573, 1531, 1519, 2291, 2243, 2240, 1989, 1504, 1850, 950, 1088, 1874, 13, 986, 1190, 1862, 857, 1636, 329, 1775, 725, 353, 623, 1163, 25, 176, 2285, 1342, 1781, 644, 908, 947, 146, 161, 1772, 1315, 365, 1160, 827, 806, 368, 1971, 989, 659, 983, 1324, 314, 713, 2321, 584, 2210, 2079, 1285, 875, 347, 653, 452, 704, 563, 386, 2022, 920, 1844, 2252, 722, 923, 1983, 1793, 2249, 845, 1166, 1651, 1339, 1618, 569, 1546, 1073, 43, 61, 16, 2216, 536, 1537, 2330, 332, 1868, 554, 28, 158, 2070, 1318, 317, 1588, 1525, 1597, 1366, 1790, 956, 109, 2246, 977, 179, 1657, 100, 881, 440, 572, 878, 1648, 575, 1426, 1561, 2303, 935, 437, 587, 2237, 929, 608, 872, 263, 1513, 1871, 944, 866, 2001, 1330, 40, 1832, 97, 842, 2207, 350, 305, 593, 149, 1886, 1303, 662, 1312, 455, 1522, 31, 2055, 1883, 115, 617, 1423, 2189, 1384, 1133, 308, 67, 296, 299, 2100, 695, 698, 1796, 1769, 464, 1823, 632, 1865, 34, 896, 1766, 1300, 692, 398, 893, 1567, 1549, 287, 1877, 1291, 134, 545, 64, 458, 611, 803, 2297, 79, 2231, 2264, 539, 1393, 1112, 1516, 124, 257, 2225, 668, 824, 2043, 2088, 19, 1082, 710, 1630, 1750, 272, 1097, 143, 1297, 719, 728, 1187, 37, 1802, 2112, 614, 1142, 1744, 2085, 278, 1606, 1411, 1600, 548, 1121, 1154, 1199, 2306, 1977, 389, 2282, 1603, 938, 656, 392, 1564, 377, 362, 815, 55, 94, 863, 1139, 91, 341, 1980, 2201, 49, 968, 103, 590, 1435, 2318, 2324, 2034, 2261, 821, 140, 1663, 980, 1633, 1, 1130, 1094, 323, 1279, 191, 446, 380, 88, 1654, 1390, 635, 2028, 167, 1543, 1321, 2031, 1838, 830, 1639, 1085, 1169, 82, 533, 416, 917, 812, 1172, 1787, 1309, 130, 449, 1381, 1612, 1582, 338, 422, 1103, 118, 914, 281, 647, 560, 2067, 293, 1070, 1570, 1585, 461, 998, 1591, 932, 992, 650, 1841, 1880, 1817, 734, 1956, 1345, 836, 2007, 926, 1552, 2279, 1968, 1615, 1106, 275, 1856, 1959, 1784, 431, 2076, 2013, 1889, 599, 1399, 1540, 566, 911, 581, 1372, 1375, 2228, 1396, 1205, 680, 1814, 707, 2270, 995, 2273, 941, 70, 2183, 73, 127, 2046, 629, 1950, 1351, 1067, 1109, 1741, 671, 1747, 2016, 410, 1151, 2255, 106, 2276, 602, 1534, 2192, 10, 58, 2267, 887, 1826, 2052, 905, 137, 2177, 1100, 1666, 1507, 1759, 185, 395, 413, 1076, 848, 1217, 683, 2294, 557, 965, 1762, 428, 701, 2198, 665, 152, 860, 2010, 383, 374, 2091, 359, 2204, 1327, 1808, 290, 1306, 1402, 425, 1363, 1763, 434, 1735, 326, 731, 266, 1835, 833, 1064, 1214, 2258, 182, 1193, 1645, 839, 320, 1432, 1181, 85, 1118, 1962, 1820, 1127, 689, 188, 809, 1202, 443, 1609, 1753, 2097, 1148, 1357, 953, 1594, 419, 2171, 899, 170, 2025, 596, 1624, 1953, 1853, 1369, 2333, 1414, 1288, 2094, 1282, 2019, 1124, 1136, 971, 1408, 2195, 2040, 1079, 1732, 1799, 2082, 2049, 2058, 1995, 1998, 1756, 1441, 677, 407, 551, 1528, 1420, 1627, 155, 356, 1348, 2004, 1829, 2180, 131, 1294, 1859, 173, 2219, 1417, 605, 1387, 1115, 974, 686, 854, 284, 674, 335, 401, 2103, 254, 1211, 1405, 2213, 818, 2288, 1196, 884, 641, 578, 716, 1558, 2061, 962, 1986, 2174, 1660, 1157, 1354, 260, 1061, 2106, 22, 626, 1175, 467, 1333, 371, 1360, 1555, 1438, 1336, 737, 1378, 1184, 869, 4, 2037, 2309, 311, 2222, 1579, 1811, 121, 1621, 1576, 1729, 46, 1429, 302, 1974, 851];
# var currentCardIndex = 0;
# </script>
#
# <script>
# init();
#
# $('#srs-showAnswer').click(e=>{
#     $('.srs-front').hide();
#     $('.srs-back').show();
# });
#
# $('#srs-wrong').click(e=>{
#     const cardId = getCardId();
#     executePython(`srs_db.Card.get(id=${cardId}).wrong()`);
#     nextCard();
# });
#
# $('#srs-right').click(e=>{
#     const cardId = getCardId();
#     executePython(`srs_db.Card.get(id=${cardId}).right()`);
#     nextCard();
# });
#
# $('#srs-easy').click(e=>{
#     const cardId = getCardId();
#     executePython(`srs_db.Card.get(id=${cardId}).right()`);
#     executePython(`srs_db.Card.get(id=${cardId}).right()`);
#     nextCard();
# });
#
# async function init() {
#     await Promise.all([
#         executePython('from srs_format import db as srs_db'),
#         executePython('import mistune')
#     ]);
#
#     renderCard();
# }
#
# function getCardId() {
#     return cardIds[currentCardIndex];
# }
#
# async function renderCard() {
#     $('.srs-front').show();
#     $('.srs-back').hide();
#
#     const cardId = getCardId();
#
#     await executePython(`sc${cardId} = srs_db.Card.get(id=${cardId})`);
#
#     await Promise.all([
#         setElementMarkdown(`sc${cardId}.front`, '#srs-front'),
#         setElementMarkdown(`sc${cardId}.back`, '#srs-back'),
#         setElementRaw(`sc${cardId}.template.model.css`, '#srs-css'),
#         setElementRaw(`sc${cardId}.template.model.js`, '#srs-js'),
#         checkSrsLevel(cardId)
#     ]);
#
#     executePython(`del sc${cardId}`);
# }
#
# async function setElementMarkdown(pyString, qSelector) {
#     const output = (await executePythonOutput(`mistune.markdown(${pyString})`)).replace(/\\n/g, '\n');
#     $(qSelector).html(output);
# }
#
# async function setElementRaw(pyString, qSelector) {
#     const output = await executePythonOutput(pyString);
#     $(qSelector).html(output);
# }
#
# async function checkSrsLevel(cardId) {
#     let srsLevel = parseInt(await executePythonOutput(`sc${cardId}.srs_level`));
#     if(isNaN(srsLevel)) srsLevel = -1;
#
#     if(srsLevel < 3) $('#srs-easy').attr('disabled', true);
#     else $('#srs-easy').attr('disabled', false);
# }
#
# function nextCard() {
#     if(currentCardIndex < cardIds.length - 1) {
#         cur
